# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import collections as c

# %% [markdown]
# ![OKCupid_Logo.svg.png](attachment:a35b9958-8ef1-4439-8e0c-2d02c1905316.png)

# %%
url1 = "okcupid_profiles.csv"
okcupid_df = pd.read_csv(url1) 
okcupid_df
# Out:
# C:\Users\liron\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       age     status sex orientation       body_type               diet  \
# 0      22     single   m    straight  a little extra  strictly anything
# 1      35     single   m    straight         average       mostly other
# 2      38  available   m    straight            thin           anything
# 3      23     single   m    straight            thin         vegetarian
# 4      29     single   m    straight        athletic                NaN
# ...    ..        ...  ..         ...             ...                ...
# 59942  59     single   f    straight             NaN                NaN
# 59943  24     single   m    straight             fit    mostly anything
# 59944  42     single   m    straight         average    mostly anything
# ...

# %%
# okcupid_df = okcupid_df.dropna()
okcupid_df.isnull().sum()
okcupid_df.reset_index().copy()
# okcupid_df.pd.to_numeric()
# Out:
#        index age     status sex orientation       body_type  \
# 0          0  22     single   m    straight  a little extra
# 1          1  35     single   m    straight         average
# 2          2  38  available   m    straight            thin
# 3          3  23     single   m    straight            thin
# 4          4  29     single   m    straight        athletic
# ...      ...  ..        ...  ..         ...             ...
# 59942  59942  59     single   f    straight             NaN
# 59943  59943  24     single   m    straight             fit
# 59944  59944  42     single   m    straight         average
# 59945  59945  27     single   m    straight        athletic
# 59946  59946  39     single   m         gay         average
#
#                     diet      drinks      drugs  \
# 0      strictly anything    socially      never
# 1           mostly other       often  sometimes
# 2               anything    socially        NaN
# ...

# %%
okcupid_df.columns = okcupid_df.columns.str.replace(' ', '')
okcupid_df = okcupid_df.astype('category')

# okcupid_df['age'] = okcupid_df.(okcupid_df['age']).copy()
okcupid_df.dtypes
# Out:
# age            category
# status         category
# sex            category
# orientation    category
# body_type      category
# diet           category
# drinks         category
# drugs          category
# education      category
# ethnicity      category
# height         category
# income         category
# job            category
# last_online    category
# location       category
# offspring      category
# pets           category
# religion       category
# sign           category
# smokes         category
# speaks         category
# dtype: object

# %%
okcupid_df['sex'].hist()
# Out:
# <AxesSubplot:>

# %%
# okcupid_df['income'].hist()
okcupid_df['age'] = pd.to_numeric(okcupid_df['age'], errors = 'coerce')
#okcupid_df['age'] = okcupid_df['age'].astype(int, errors = 'raise')
okcupid_df['income'] = pd.to_numeric(okcupid_df['income'], errors = 'coerce')
okcupid_df['height'] = pd.to_numeric(okcupid_df['height'], errors = 'coerce')
okcupid_df.dtypes
# Out:
# age             float64
# status         category
# sex            category
# orientation    category
# body_type      category
# diet           category
# drinks         category
# drugs          category
# education      category
# ethnicity      category
# height          float64
# income          float64
# job            category
# last_online    category
# location       category
# offspring      category
# pets           category
# religion       category
# sign           category
# smokes         category
# speaks         category
# dtype: object

# %%
c.Counter(okcupid_df['status']).most_common(20)
df = pd.DataFrame.from_records(c.Counter(okcupid_df['status']).most_common(10), columns=['status','count_status'])

# df[['sex','count_sex']] = pd.DataFrame.from_records(c.Counter(okcupid_df['sex']).most_common(20), columns=['page','count'])
# df[['pets','count_pets']] = pd.DataFrame.from_records(c.Counter(okcupid_df['pets']).most_common(20), columns=['page','count'])
# df[['body_type','count_body_type']] = pd.DataFrame.from_records(c.Counter(okcupid_df['body_type']).most_common(20), columns=['page','count'])
# df[['drugs','count_drugs']] = pd.DataFrame.from_records(c.Counter(okcupid_df['drugs']).most_common(20), columns=['page','count'])
# df[['drinks','count_drinks']] = pd.DataFrame.from_records(c.Counter(okcupid_df['drinks']).most_common(20), columns=['page','count'])
# df[['height','count_height']] = pd.DataFrame.from_records(c.Counter(okcupid_df['height']).most_common(50), columns=['page','count'])

# %%
# df_to_plot = df.drop(columns=['status','sex', 'pets','body_type','drugs','drinks'])
# df_to_plot.plot(subplots=True, layout=(5,4), kind='box', figsize=(12,14), patch_artist=True)
# plt.subplots_adjust(wspace=0.5);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-e3ec7b93b144> in <module>
# ----> 1 df_to_plot = df.drop(columns=['status','sex', 'pets','body_type','drugs','drinks'])
#       2 df_to_plot.plot(subplots=True, layout=(5,4), kind='box', figsize=(12,14), patch_artist=True)
#       3 plt.subplots_adjust(wspace=0.5);
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
plt.figure(1, figsize=(5,5))
plt.title("Distribution of Species")
okcupid_df['income'].value_counts().plot.pie(autopct="%1.1f%%") #try removing this - what happens?
plt.ylabel("")  #try removing this - what happens?
plt.show()

# %%
# sns.regplot(x='age', y='drugs', data=okcupid_df)c
okcupid_df['income'].hist()
# Out:
# <AxesSubplot:>

# %%
# features = ['income', 'drugs','sex','age']
# fig, axes = plt.subplots(2,2,figsize=(15,15))
# plt.subplots_adjust(wspace=0.5, hspace = 0.3)
# axes = axes.flatten()
# for i,att in enumerate(features):
#     sns.histplot(x=att, data=okcupid_df,  ax=axes[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1522         try:
# -> 1523             ret = self.converter.convert(x, self.units, self)
#    1524         except Exception as e:
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      60         # force an update so it also does type checking
# ---> 61         unit.update(values)
#      62         return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     210             # OrderedDict just iterates over unique values in data.
# --> 211             cbook._check_isinstance((str, bytes), value=val)
#     212             if convertible:
#
# ...
